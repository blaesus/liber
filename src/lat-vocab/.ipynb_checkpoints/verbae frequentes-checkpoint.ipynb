# %%
from collections import Counter
from cltk.stem.lemma import LemmaReplacer
from cltk.stem.latin.j_v import JVReplacer
from cltk.prosody.latin.macronizer import Macronizer
import cltk.corpus.latin

lemmatizer = LemmaReplacer('latin')
macronizer = Macronizer('tag_ngram_123_backoff')
jv_replacer = JVReplacer()

nonword_name_abbreviations = 'Ap,A,D,F,C,Cn,H,L,Mai,Mam,M,Min,N,Oct,P,Q,Seq,Ser,Sp,St,T,Ti,V,Vol,Vop'.lower().split(',')

def clean_entry(entry):
    if (entry in nonword_name_abbreviations):
        return entry.capitalize()+'.'
    return ''.join(filter(lambda x: x.isalpha(), entry))

def get_corpus_files(author):
    fileids = filter(lambda s: s.startswith(author), cltk.corpus.latin.latinlibrary.fileids())
    files = [cltk.corpus.latin.latinlibrary.abspath(fileid) for fileid in fileids]
    return files

def merge_file_contents(paths):
    text = ''
    for path in files:
        f = open(path)
        text += f.read()
        #print('loaded', path, 'buffer length', len(text))
        f.close()
    return text

# %%
authors = (
    'caesar',
    'livy',
#     'cato',
#     'ovid',
#     'more',
)

data = {}
for author in authors:
    freq_table = []

    files = get_corpus_files(author)
    text = merge_file_contents(files)
    text = clean_text(text)

    tokens = lemmatizer.lemmatize(jv_replacer.replace(text).lower())
    N = len(tokens)
    longest_token = max(tokens, key=len)
    freq_count = Counter(tokens)
    data[author] = freq_count

# %%
def normalize(freq_table):
    result = freq_table.copy()
    N = sum(freq_table.values())
    for lemma in result:
        result[lemma] /= N
    return result

def normalize_all(data):
    result = data.copy()
    for author in result:
        result[author] = normalize(result[author])
    return result

def merge_all(data):
    result = Counter()
    for author in data:
        result += data[author]
    return result

def percent(n, decimal=2):
    return '{:.{decimal}f}'.format(n * 100, decimal=decimal) + '%'

def word_use_detail(word, author):
    author_data = data[author]
    N = sum(author_data.values())
    return author + ':' + str(percent(author_data[word] / N, 2))

    

PERIOD = 100
LAST_WORD = 10000

def print_counter_data(counter):
    coverage = 0
    N = sum(counter.values())
    index = 1
    for word, freq in counter.most_common(LAST_WORD):
        coverage += freq / N
        if index == 1 or index % PERIOD == 0:

            details = ' '.join([word_use_detail(word, author) for author in authors])
            print(
                '%5s' % index,
                '%-15s' % clean_entry(word),
                '%6s' % percent(freq, 3),
                '(%5s)' % percent(coverage, 1),
                details,
            )
        index += 1

normalized_combined_freq_table = normalize(merge_all(data))
print_counter_data(normalized_combined_freq_table)
# Out:
#     1 qui             2.744% ( 2.7%) caesar:3.30% livy:2.62%
#   100 copia           0.147% (41.8%) caesar:0.35% livy:0.10%
#   200 deus            0.080% (52.7%) caesar:0.01% livy:0.09%
#   300 libertas        0.056% (59.3%) caesar:0.03% livy:0.06%
#   400 hispania        0.040% (64.1%) caesar:0.02% livy:0.04%
#   500 quiesco         0.033% (67.7%) caesar:0.01% livy:0.04%
#   600 semper          0.027% (70.7%) caesar:0.03% livy:0.03%
#   700 rursus          0.023% (73.2%) caesar:0.06% livy:0.02%
#   800 dives           0.020% (75.3%) caesar:0.00% livy:0.02%
#   900 effero          0.017% (77.2%) caesar:0.02% livy:0.02%
#  1000 licinus         0.015% (78.8%) caesar:0.00% livy:0.02%
#  1100 initio          0.014% (80.2%) caesar:0.02% livy:0.01%
#  1200 contemno        0.012% (81.6%) caesar:0.01% livy:0.01%
#  1300 consulto        0.011% (82.7%) caesar:0.00% livy:0.01%
#  1400 sperno          0.010% (83.7%) caesar:0.00% livy:0.01%
#  1500 vinum           0.009% (84.6%) caesar:0.00% livy:0.01%
#  1600 admoneo         0.008% (85.5%) caesar:0.01% livy:0.01%
#  1700 catus           0.007% (86.2%) caesar:0.01% livy:0.01%
#  1800 emineo          0.007% (86.9%) caesar:0.01% livy:0.01%
#  1900 conduco         0.006% (87.5%) caesar:0.01% livy:0.01%
#  2000 navigium        0.005% (88.1%) caesar:0.02% livy:0.00%
#  2100 studeo          0.005% (88.7%) caesar:0.02% livy:0.00%
#  2200 descio          0.005% (89.1%) caesar:0.00% livy:0.01%
#  2300 veho            0.004% (89.6%) caesar:0.01% livy:0.00%
#  2400 careo           0.004% (90.0%) caesar:0.00% livy:0.00%
#  2500 dictito         0.004% (90.4%) caesar:0.00% livy:0.00%
#  2600 ltadgt          0.004% (90.8%) caesar:0.00% livy:0.00%
#  2700 ascendo         0.003% (91.1%) caesar:0.01% livy:0.00%
#  2800 ariouistus      0.003% (91.5%) caesar:0.02% livy:0.00%
#  2900 prehendo        0.003% (91.8%) caesar:0.00% livy:0.00%
#  3000 cremo           0.003% (92.0%) caesar:0.00% livy:0.00%
#  3100 advena          0.003% (92.3%) caesar:0.00% livy:0.00%
#  3200 oceano          0.003% (92.6%) caesar:0.01% livy:0.00%
#  3300 salvo           0.002% (92.8%) caesar:0.00% livy:0.00%
#  3400 notitia         0.002% (93.1%) caesar:0.01% livy:0.00%
#  3500 immeritus       0.002% (93.3%) caesar:0.00% livy:0.00%
#  3600 fautor          0.002% (93.5%) caesar:0.00% livy:0.00%
#  3700 clientela       0.002% (93.7%) caesar:0.01% livy:0.00%
#  3800 ltsigt          0.002% (93.9%) caesar:0.00% livy:0.00%
#  3900 adscio          0.002% (94.0%) caesar:0.00% livy:0.00%
#  4000 lentulum        0.002% (94.2%) caesar:0.00% livy:0.00%
#  4100 silex           0.002% (94.4%) caesar:0.00% livy:0.00%
#  4200 europae         0.002% (94.5%) caesar:0.00% livy:0.00%
#  4300 muralis         0.001% (94.7%) caesar:0.00% livy:0.00%
#  4400 sardorum        0.001% (94.8%) caesar:0.00% livy:0.00%
#  4500 eniteo          0.001% (94.9%) caesar:0.00% livy:0.00%
#  4600 semirutus       0.001% (95.1%) caesar:0.00% livy:0.00%
#  4700 maroneam        0.001% (95.2%) caesar:0.00% livy:0.00%
#  4800 xxuiii          0.001% (95.3%) caesar:0.00% livy:0.00%
#  4900 umbria          0.001% (95.4%) caesar:0.00% livy:0.00%
#  5000 exauctoro       0.001% (95.5%) caesar:0.00% livy:0.00%
#  5100 brundisii       0.001% (95.6%) caesar:0.00% livy:0.00%
#  5200 carnutum        0.001% (95.7%) caesar:0.01% livy:0.00%
#  5300 palus           0.001% (95.8%) caesar:0.00% livy:0.00%
#  5400 paeligni        0.001% (95.9%) caesar:0.00% livy:0.00%
#  5500 conpono         0.001% (96.0%) caesar:0.00% livy:0.00%
#  5600 obsessio        0.001% (96.1%) caesar:0.00% livy:0.00%
#  5700 carteiam        0.001% (96.2%) caesar:0.00% livy:0.00%
#  5800 demptum         0.001% (96.2%) caesar:0.00% livy:0.00%
#  5900 aspretum        0.001% (96.3%) caesar:0.00% livy:0.00%
#  6000 semestris       0.001% (96.4%) caesar:0.00% livy:0.00%
#  6100 cortex          0.001% (96.5%) caesar:0.00% livy:0.00%
#  6200 seruaturum      0.001% (96.5%) caesar:0.00% livy:0.00%
#  6300 graeca          0.001% (96.6%) caesar:0.00% livy:0.00%
#  6400 devasto         0.001% (96.7%) caesar:0.00% livy:0.00%
#  6500 septeni         0.001% (96.7%) caesar:0.00% livy:0.00%
#  6600 andrum          0.001% (96.8%) caesar:0.00% livy:0.00%
#  6700 bacchis         0.001% (96.8%) caesar:0.00% livy:0.00%
#  6800 derivo          0.000% (96.9%) caesar:0.00% livy:0.00%
#  6900 neapoli         0.000% (97.0%) caesar:0.00% livy:0.00%
#  7000 ferax           0.000% (97.0%) caesar:0.00% livy:0.00%
#  7100 ursaonem        0.000% (97.0%) caesar:0.00% livy:0.00%
#  7200 sophus          0.000% (97.1%) caesar:0.00% livy:0.00%
#  7300 supellectilem   0.000% (97.1%) caesar:0.00% livy:0.00%
#  7400 uolturnus       0.000% (97.2%) caesar:0.00% livy:0.00%
#  7500 obtestatio      0.000% (97.2%) caesar:0.00% livy:0.00%
#  7600 pandosia        0.000% (97.3%) caesar:0.00% livy:0.00%
#  7700 pisistrato      0.000% (97.3%) caesar:0.00% livy:0.00%
#  7800 celaenis        0.000% (97.4%) caesar:0.00% livy:0.00%
#  7900 macedonasque    0.000% (97.4%) caesar:0.00% livy:0.00%
#  8000 lxxiu           0.000% (97.5%) caesar:0.00% livy:0.00%
#  8100 cornificius     0.000% (97.5%) caesar:0.00% livy:0.00%
#  8200 bipedalis       0.000% (97.5%) caesar:0.00% livy:0.00%
#  8300 aucupo          0.000% (97.6%) caesar:0.00% livy:0.00%
#  8400 stipendiarii    0.000% (97.6%) caesar:0.00% livy:0.00%
#  8500 sumptuosus      0.000% (97.6%) caesar:0.00% livy:0.00%
#  8600 capye           0.000% (97.7%) caesar:0.00% livy:0.00%
#  8700 gabinorum       0.000% (97.7%) caesar:0.00% livy:0.00%
#  8800 cloelia         0.000% (97.7%) caesar:0.00% livy:0.00%
#  8900 satisfacturum   0.000% (97.8%) caesar:0.00% livy:0.00%
#  9000 pythion         0.000% (97.8%) caesar:0.00% livy:0.00%
#  9100 panormi         0.000% (97.8%) caesar:0.00% livy:0.00%
#  9200 oeniadas        0.000% (97.9%) caesar:0.00% livy:0.00%
#  9300 coarto          0.000% (97.9%) caesar:0.00% livy:0.00%
#  9400 praeferox       0.000% (97.9%) caesar:0.00% livy:0.00%
#  9500 canastraeum     0.000% (98.0%) caesar:0.00% livy:0.00%
#  9600 ptolomaeumque   0.000% (98.0%) caesar:0.00% livy:0.00%
#  9700 apamam          0.000% (98.0%) caesar:0.00% livy:0.00%
#  9800 argitheam       0.000% (98.0%) caesar:0.00% livy:0.00%
#  9900 corniculana     0.000% (98.1%) caesar:0.00% livy:0.00%
# 10000 alpis           0.000% (98.1%) caesar:0.00% livy:0.00%
